# %%
import GWDALI as gw
import numpy as np
import matplotlib.pyplot as plt
from corner import corner
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %% [markdown]
# ### Setting Networks

# %%
det_ET1 = {'name':'ET','lon':6, 'lat':50, 'rot':0, 'shape':60}
det_ET2 = {'name':'ET','lon':6, 'lat':50, 'rot':120, 'shape':60}
det_ET3 = {'name':'ET','lon':6, 'lat':50, 'rot':-120, 'shape':60}
detectors = [det_ET1, det_ET2, det_ET3]

fig = gw.draw_detectors(detectors)

# %% [markdown]
# ### Setting GW Source Propertites

# %%
GwPrms = {}                                                                                                
GwPrms['dL'] 	= 10.96
GwPrms['Mc'] 	= 9.57
GwPrms['eta'] 	= 0.25
GwPrms['iota'] 	= 0.52
GwPrms['psi'] 	= 2.32
GwPrms['t_coal'] 	= 0.00
GwPrms['phi_coal'] 	= -1.37
GwPrms['RA'] 	= -135.75
GwPrms['Dec'] 	= 72.92
GwPrms['sz1'] 	= 0.31
GwPrms['sz2'] 	= 0.16

GwPrms['sx1'] 	= 0.00
GwPrms['sy1'] 	= 0.00

GwPrms['sx2'] 	= 0.00
GwPrms['sy2'] 	= 0.00

# %% [markdown]
# ### Loading Precomputed DALI Tensors

# %%
tensors = np.load("DaliTensors.npz")

Fisher = tensors["Fisher"]
Db12   = tensors["Db12"]
Db22   = tensors["Db22"]
Tp13   = tensors["Tp13"]
Tp23   = tensors["Tp23"]
Tp33   = tensors["Tp33"]

Doublet = [Db12, Db22]
Triplet = [Tp13, Tp23, Tp33]

dali_tensors = [Fisher, Doublet, Triplet]

# %% [markdown]
# ### Running GWDALI (Doublet)
# - Doublet-DALI With Tensors Pre-Computed

# %%
res_Db = gw.GWDALI(	GwPrms=GwPrms,
					detectors=detectors,
					FreeParams=["dL","iota"], # Free Parameters
					approx = "TaylorF2",
					method="Doublet",
					sampler="nestle",
					new_priors = None,
					#dali_tensors = dali_tensors,
					plot_signal=False,
					nlive = 300, # nlive for nested sampling
                    # nsteps = None,
					# nwalkers = None,
					# ntemps = None,
					remove_out=True, # Remove output path
					verbose = True,
					hide_info = False, # Hide GWDALI informatins
					output_name=f'gwdali_output/'
				)

print("GWDALI (Doublet) concluded!")
# Out:
# #==============================
# ... Running GWDALI_v1 ...
# #==============================
#
#
#  Free Parameters:  ['dL', 'iota']
#  Method:  Doublet
#  Approx:  TaylorF2
#
# >> Injections:
# 	 dL: 10.96
# 	 Mc: 9.57
# 	 eta: 0.25
# 	 iota: 0.52
# 	 psi: 2.32
# 	 t_coal: 0.00
# 	 phi_coal: -1.37
# 	 RA: -135.75
# 	 Dec: 72.92
# 	 sz1: 0.31
# 	 sz2: 0.16
# 	 sx1: 0.00
# 	 sy1: 0.00
# 	 sx2: 0.00
# 	 sy2: 0.00
#
#
# ET (1) SNR = 12.981907492411947
# ET (2) SNR = 12.676552183767917
# ET (3) SNR = 11.52371525738471
# Computing Tensors ...
# Loading JAX derivatives ...
#
# *********************************** [1] Detector: ET ***********************************
#
# 	 loading <autodiff> derivatives ...
# 		>> jitgrad = False...
# 	 <autodiff> derivatives loaded!
#
#
# ==================================== Computing DALI Tensors (Doublet) ====================================
#
#
#
#  # Computing First-Order Derivatives (diff_method = autodiff) .....
#
# 	 (dL)	 [1-2]	 Diff[dL] OK! 	(0 seconds)
# 	 (iota)	 [2-2]	 Diff[iota] OK! 	(0 seconds)
#
# >> First Derivatives Concluded in 0min:1sec!
#
#
#
# 	Fisher(1|1) [1,1] ..............................
#
# Computing Second-Order Derivatives ...
# 	 (dL,dL)	 [1-3]	 Diff[dL,dL] OK! 	(0 seconds)
# 	 (iota,dL)	 [2-3]	 Diff[iota,dL] OK! 	(0 seconds)
# 	 (iota,iota)	 [3-3]	 Diff[iota,iota] OK! 	(0 seconds)
#
# >> Second Derivatives Concluded in 0min:1sec!
#
#
#
# Doublet(1|2) [(1, 1, 1)]  ..............................
# Doublet(2|2) [(1, 1, 1, 1)]  ..............................
#
#
# *********************************** [2] Detector: ET ***********************************
#
# 	 loading <autodiff> derivatives ...
# 		>> jitgrad = False...
# 	 <autodiff> derivatives loaded!
#
#
# ==================================== Computing DALI Tensors (Doublet) ====================================
#
#
#
#  # Computing First-Order Derivatives (diff_method = autodiff) .....
#
# 	 (dL)	 [1-2]	 Diff[dL] OK! 	(0 seconds)
# 	 (iota)	 [2-2]	 Diff[iota] OK! 	(0 seconds)
#
# >> First Derivatives Concluded in 0min:0sec!
#
#
#
# 	Fisher(1|1) [1,1] ..............................
#
# Computing Second-Order Derivatives ...
# 	 (dL,dL)	 [1-3]	 Diff[dL,dL] OK! 	(0 seconds)
# 	 (iota,dL)	 [2-3]	 Diff[iota,dL] OK! 	(0 seconds)
# 	 (iota,iota)	 [3-3]	 Diff[iota,iota] OK! 	(0 seconds)
#
# >> Second Derivatives Concluded in 0min:1sec!
#
#
#
# Doublet(1|2) [(1, 1, 1)]  ..............................
# Doublet(2|2) [(1, 1, 1, 1)]  ..............................
#
#
# *********************************** [3] Detector: ET ***********************************
#
# 	 loading <autodiff> derivatives ...
# 		>> jitgrad = False...
# 	 <autodiff> derivatives loaded!
#
#
# ==================================== Computing DALI Tensors (Doublet) ====================================
#
#
#
#  # Computing First-Order Derivatives (diff_method = autodiff) .....
#
# 	 (dL)	 [1-2]	 Diff[dL] OK! 	(0 seconds)
# 	 (iota)	 [2-2]	 Diff[iota] OK! 	(0 seconds)
#
# >> First Derivatives Concluded in 0min:0sec!
#
#
#
# 	Fisher(1|1) [1,1] ..............................
#
# Computing Second-Order Derivatives ...
# 	 (dL,dL)	 [1-3]	 Diff[dL,dL] OK! 	(0 seconds)
# 	 (iota,dL)	 [2-3]	 Diff[iota,dL] OK! 	(0 seconds)
# 	 (iota,iota)	 [3-3]	 Diff[iota,iota] OK! 	(0 seconds)
#
# >> Second Derivatives Concluded in 0min:1sec!
#
#
#
# Doublet(1|2) [(1, 1, 1)]  ..............................
# Doublet(2|2) [(1, 1, 1, 1)]  ..............................
#
#
# >> DALI-Tensors OK!
#
#
#  Running Sampler (nestle)...
#
# it=  1492 logz=-4.540279991416
# GWDALI (Doublet) concluded!

# %% [markdown]
# ### Running GWDALI (Exact)

# %%
res_Ex = gw.GWDALI(	GwPrms=GwPrms,
					detectors=detectors,
					FreeParams=["dL","iota"], # Free Parameters
					approx = "TaylorF2",
					method = "Exact",
					sampler="nestle",
					new_priors = None,
					# dali_tensors = dali_tensors, # Not used for Exact Likelihoods
					plot_signal=False,
					nlive = 300, # nlive for nested sampling
                    # nsteps = None,
					# nwalkers = None,
					# ntemps = None,
					remove_out=True, # Remove output path
					verbose = True,
					hide_info = False, # Hide GWDALI informatins
					output_name=f'gwdali_output/'
				)

print("GWDALI (Exact) concluded!")
# Out:
# #==============================
# ... Running GWDALI_v1 ...
# #==============================
#
#
#  Free Parameters:  ['dL', 'iota']
#  Method:  Exact
#  Approx:  TaylorF2
#
# >> Injections:
# 	 dL: 10.96
# 	 Mc: 9.57
# 	 eta: 0.25
# 	 iota: 0.52
# 	 psi: 2.32
# 	 t_coal: 0.00
# 	 phi_coal: -1.37
# 	 RA: -135.75
# 	 Dec: 72.92
# 	 sz1: 0.31
# 	 sz2: 0.16
# 	 sx1: 0.00
# 	 sy1: 0.00
# 	 sx2: 0.00
# 	 sy2: 0.00
#
#
# ET (1) SNR = 12.981907492411947
# ET (2) SNR = 12.676552183767917
# ET (3) SNR = 11.52371525738471
# Computing Tensors ...
#
# >> DALI-Tensors OK!
#
#
#  Running Sampler (nestle)...
#
# it=  1668 logz=-5.126549170
# GWDALI (Exact) concluded!

# %% [markdown]
# ### Reading Results

# %%
Results, Truths, Tensors, Fisher_Matrix, Time = res_Db

time_dali, time_mcmc = Time

samples_Db, priors, likelihood_times_Db, Evidence = Results

logZ, logZ_err = Evidence # Valid only for Nested Sampling

print(f"log(Evidence) = {logZ:.2f} +- {logZ_err:.2f}")
# Out:
# log(Evidence) = -4.08 +- 0.11

# %%
samples_Ex = res_Ex[0][0]
likelihood_times_Ex = res_Ex[0][2]

# %% [markdown]
# ### Plotting Results with Corner

# %%
fig = corner(   samples_Db,
                smooth1d = 2,
                smooth = 2,
                bins = 60,
                color = "b",
                levels = [0.6,0.9],
                plot_density = False,
                plot_datapoints = False,
                labels = ["$d_L$","$\\iota$"],
                truths = [ GwPrms["dL"],GwPrms["iota"] ], 
                truth_color='r',
                #quantiles = [0.2,0.5,0.8],
                show_titles = True
            )

corner( samples_Ex,
        smooth1d = 2,
        smooth = 2,
        bins = 60,
        color = "k",
        fig = fig,
        levels = [0.6,0.9],
        plot_density = False,
        plot_datapoints = False,
        )

plt.plot([],'k-',label='Exact')
plt.plot([],'b-',label='Doublet')
fig.legend(loc='upper right')

plt.show()

# %%
# The first likelihood evaluation is every the slower
plt.hist(np.sort(likelihood_times_Ex)[:-2]/1.e-2,bins=60,color='k',lw=2,histtype='step',density=True)
plt.hist(likelihood_times_Db[1:]/1.e-2,bins=60,color='b',lw=2,histtype='step',density=True)
plt.xlabel('likelihood evaluation time [ms]')
plt.title(f"Total of {len(likelihood_times_Db)} likelihoods evaluations (Doublet)")
plt.xlim(0.1,0.45)
plt.grid()
plt.show()

# %% [markdown]
# ## Solving Problem of Bimodality in $d_L$ for Doublet
# * $d_L\rightarrow 1/d_L$

# %%
GwPrms2 = {}
for key in GwPrms.keys():
    if key!="dL": 
        GwPrms2[key] = GwPrms[key]
    else:
        GwPrms2["inv_dL"] = 1./GwPrms["dL"]

res_Db_v2 = gw.GWDALI(	GwPrms=GwPrms2,
                        detectors=detectors,
                        FreeParams=["inv_dL","iota"], # Free Parameters
                        approx = "TaylorF2",
                        method = "Doublet",
                        sampler="nestle",
                        new_priors = None,
                        # dali_tensors = dali_tensors, # Not used for Exact Likelihoods
                        diff_method = "numdiff",
                        plot_signal=False,
                        nlive = 300, # nlive for nested sampling
                        # nsteps = None,
                        # nwalkers = None,
                        # ntemps = None,
                        remove_out=True, # Remove output path
                        verbose = True,
                        hide_info = False, # Hide GWDALI informatins
                        output_name=f'gwdali_output/'
                    )

print("GWDALI (Doublet: 1/dL) concluded!")
# Out:
# #==============================
# ... Running GWDALI_v1 ...
# #==============================
#
#
#  Free Parameters:  ['inv_dL', 'iota']
#  Method:  Doublet
#  Approx:  TaylorF2
#
# >> Injections:
# 	 inv_dL: 0.09
# 	 Mc: 9.57
# 	 eta: 0.25
# 	 iota: 0.52
# 	 psi: 2.32
# 	 t_coal: 0.00
# 	 phi_coal: -1.37
# 	 RA: -135.75
# 	 Dec: 72.92
# 	 sz1: 0.31
# 	 sz2: 0.16
# 	 sx1: 0.00
# 	 sy1: 0.00
# 	 sx2: 0.00
# 	 sy2: 0.00
#
#
# ET (1) SNR = 12.981907492411947
# ET (2) SNR = 12.676552183767917
# ET (3) SNR = 11.52371525738471
# Computing Tensors ...
# Loading JAX derivatives ...
#
# *********************************** [1] Detector: ET ***********************************
#
#
# ==================================== Computing DALI Tensors (Doublet) ====================================
#
#
#
#  # Computing First-Order Derivatives (diff_method = numdiff) .....
#
# 	 (inv_dL)	 [1-2]	 Diff[inv_dL] OK! 	(0 seconds)
# 	 (iota)	 [2-2]	 Diff[iota] OK! 	(0 seconds)
#
# >> First Derivatives Concluded in 0min:0sec!
#
#
#
# 	Fisher(1|1) [1,1] ..............................
#
# Computing Second-Order Derivatives ...
# 	 (inv_dL,inv_dL)	 [1-3]	 Diff[inv_dL,inv_dL] OK! 	(0 seconds)
# 	 (iota,inv_dL)	 [2-3]	 Diff[iota,inv_dL] OK! 	(0 seconds)
# 	 (iota,iota)	 [3-3]	 Diff[iota,iota] OK! 	(0 seconds)
#
# >> Second Derivatives Concluded in 0min:1sec!
#
#
#
# Doublet(1|2) [(1, 1, 1)]  ..............................
# Doublet(2|2) [(1, 1, 1, 1)]  ..............................
#
#
# *********************************** [2] Detector: ET ***********************************
#
#
# ==================================== Computing DALI Tensors (Doublet) ====================================
#
#
#
#  # Computing First-Order Derivatives (diff_method = numdiff) .....
#
# 	 (inv_dL)	 [1-2]	 Diff[inv_dL] OK! 	(0 seconds)
# 	 (iota)	 [2-2]	 Diff[iota] OK! 	(0 seconds)
#
# >> First Derivatives Concluded in 0min:0sec!
#
#
#
# 	Fisher(1|1) [1,1] ..............................
#
# Computing Second-Order Derivatives ...
# 	 (inv_dL,inv_dL)	 [1-3]	 Diff[inv_dL,inv_dL] OK! 	(0 seconds)
# 	 (iota,inv_dL)	 [2-3]	 Diff[iota,inv_dL] OK! 	(0 seconds)
# 	 (iota,iota)	 [3-3]	 Diff[iota,iota] OK! 	(0 seconds)
#
# >> Second Derivatives Concluded in 0min:1sec!
#
#
#
# Doublet(1|2) [(1, 1, 1)]  ..............................
# Doublet(2|2) [(1, 1, 1, 1)]  ..............................
#
#
# *********************************** [3] Detector: ET ***********************************
#
#
# ==================================== Computing DALI Tensors (Doublet) ====================================
#
#
#
#  # Computing First-Order Derivatives (diff_method = numdiff) .....
#
# 	 (inv_dL)	 [1-2]	 Diff[inv_dL] OK! 	(0 seconds)
# 	 (iota)	 [2-2]	 Diff[iota] OK! 	(0 seconds)
#
# >> First Derivatives Concluded in 0min:0sec!
#
#
#
# 	Fisher(1|1) [1,1] ..............................
#
# Computing Second-Order Derivatives ...
# 	 (inv_dL,inv_dL)	 [1-3]	 Diff[inv_dL,inv_dL] OK! 	(0 seconds)
# 	 (iota,inv_dL)	 [2-3]	 Diff[iota,inv_dL] OK! 	(0 seconds)
# 	 (iota,iota)	 [3-3]	 Diff[iota,iota] OK! 	(0 seconds)
#
# >> Second Derivatives Concluded in 0min:1sec!
#
#
#
# Doublet(1|2) [(1, 1, 1)]  ..............................
# Doublet(2|2) [(1, 1, 1, 1)]  ..............................
#
#
# >> DALI-Tensors OK!
#
#
#  Running Sampler (nestle)...
#
# it=  1624 logz=-4.9820353124
# GWDALI (Doublet: 1/dL) concluded!

# %% [markdown]
# ### Comparing Exact x Doublet ($d_L$) x Doublet ($d_L^{-1}$)

# %%
samples_Db_v2 = res_Db_v2[0][0]
likelihood_times_Db_v2 = res_Db_v2[0][2]

# %%
fig = corner(   samples_Db,
                smooth1d = 2,
                smooth = 2,
                bins = 60,
                color = "b",
                levels = [0.6,0.9],
                plot_density = False,
                plot_datapoints = False,
                labels = ["$d_L$","$\\iota$"],
                truths = [ GwPrms["dL"],GwPrms["iota"] ], 
                truth_color='g',
                #quantiles = [0.2,0.5,0.8],
                show_titles = True
            )

x, y = samples_Db_v2.T
x = 1./x
samples2 = np.transpose([x,y])

corner( samples2,
        smooth1d = 2,
        smooth = 2,
        bins = 60,
        color = "r",
        fig = fig,
        levels = [0.6,0.9],
        plot_density = False,
        plot_datapoints = False,
        )

corner( samples_Ex,
        smooth1d = 2,
        smooth = 2,
        bins = 60,
        color = "k",
        fig = fig,
        levels = [0.6,0.9],
        plot_density = False,
        plot_datapoints = False,
        )

plt.plot([],'k-',label='Exact')
plt.plot([],'b-',label='Doublet ($d_L$)')
plt.plot([],'r-',label='Doublet ($1/d_L$)')
plt.plot([],'g-',label='Injection')
fig.legend(loc='upper right')

plt.show()
